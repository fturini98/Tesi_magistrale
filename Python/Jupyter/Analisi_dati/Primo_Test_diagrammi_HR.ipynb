# %% [markdown]
# Carico le funzioni scritte in ../Generici/Lettura_file_layout_strano.ipynb

# %%
import sys
sys.path.append('../../Python/')
from Generici.Lettura_file_layout_strano import *
#%run ../../Python/Lettura_file_layout_strano.py

# %% [markdown]
# Carico i file dal seguente file path

# %%
folder_path="C:/Users/fturi/Desktop/Uni/Tesi magistrale/Dati/Test/tools-driver-out/M0.76_Z0.00135_He0.2499_ML1.90_55555555_AS09a0"
file_name="OUT.dat"
file_path=folder_path + '/' +file_name


data = read_data(file_path)

# %% [markdown]
# Faccio i plot dell'ipotetico diagramma HR

# %%
import matplotlib.pyplot as plt

log_L=data['LOG_L']
log_Te=data['LOG_TE']

plt.plot(log_Te, log_L)
plt.xlabel('LOG Teff')
plt.ylabel('LOG L ')
plt.title('Diagramma H-R')
plt.gca().invert_xaxis()
plt.grid(True)
plt.show()
